# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Travel.csv")

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
round(100 * df.isnull().sum()/len(df.index),2)
# Out:
# CustomerID                  0.00
# ProdTaken                   0.00
# Age                         4.62
# TypeofContact               0.51
# CityTier                    0.00
# DurationOfPitch             5.14
# Occupation                  0.00
# Gender                      0.00
# NumberOfPersonVisiting      0.00
# NumberOfFollowups           0.92
# ProductPitched              0.00
# PreferredPropertyStar       0.53
# MaritalStatus               0.00
# NumberOfTrips               2.86
# Passport                    0.00
# PitchSatisfactionScore      0.00
# OwnCar                      0.00
# NumberOfChildrenVisiting    1.35
# Designation                 0.00
# MonthlyIncome               4.77
# dtype: float64

# %%
# df.dropna(axis = 0 , inplace = True)

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.Gender . unique()
# Out:
# array(['Female', 'Male', 'Fe Male'], dtype=object)

# %%
df.replace('Fe Male','Female', inplace = True)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cols_cat = [col for col in df.columns if df[col].dtype == 'object']
cols_nums = [col for col in df.columns if df[col].dtype != 'object']

# %%
cols_cat
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
cols_nums
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
for cat_columns in cols_cat:
    plt.figure(figsize = (6,3))
    sns.countplot(x = cat_columns, data = df , palette = 'muted')
    plt.title("count plot for cat_colmns")
    plt.show()

# %%
for num_columns in cols_nums:
    plt.figure(figsize = (6,3))
    sns.boxplot(x = num_columns, data = df , palette = 'muted')
    plt.title("count plot for cat_colmns")
    plt.show()

# %%
plt.hist(df['Age'].dropna(),bins = 40 ,color = 'orange',edgecolor = 'black')
plt.title("dist. betw the age")
plt.xlabel("Age")
plt.ylabel("count")
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
sns.countplot(x = 'CityTier', data = df , palette = 'muted')
# Out:
# <Axes: xlabel='CityTier', ylabel='count'>

# %%
df.Gender.value_counts().plot.pie(autopct = '%1.1f%%', explode = (0,0.2),shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %%
df[cols_nums].describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %%
df[cols_nums] = df[cols_nums].astype('object')

# %%
df[cols_nums].describe()
# Out:
#         CustomerID  ProdTaken     Age  CityTier  DurationOfPitch  \
# count         4888       4888  4662.0      4888           4637.0
# unique        4888          2    44.0         3             34.0
# top         200000          0    35.0         1              9.0
# freq             1       3968   237.0      3190            483.0
#
#         NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count                     4888             4843.0                 4862.0
# unique                       5                6.0                    3.0
# top                          3                4.0                    3.0
# freq                      2402             2068.0                 2993.0
#
#         NumberOfTrips  Passport  PitchSatisfactionScore  OwnCar  \
# count          4748.0      4888                    4888    4888
# unique           12.0         2                       5       2
# top               2.0         0                       3       1
# ...

# %%
for i in df[cols_nums].columns:
    x = df[i].unique()
    print(f"{i}:{x}")
    print()
# Out:
# CustomerID:[200000 200001 200002 ... 204885 204886 204887]
#
# ProdTaken:[1 0]
#
# Age:[41.0 49.0 37.0 33.0 nan 32.0 59.0 30.0 38.0 36.0 35.0 31.0 34.0 28.0 29.0
#  22.0 53.0 21.0 42.0 44.0 46.0 39.0 24.0 43.0 50.0 27.0 26.0 48.0 55.0
#  45.0 56.0 23.0 51.0 40.0 54.0 58.0 20.0 25.0 19.0 57.0 52.0 47.0 18.0
#  60.0 61.0]
#
# CityTier:[3 1 2]
#
# DurationOfPitch:[6.0 14.0 8.0 9.0 30.0 29.0 33.0 22.0 21.0 32.0 25.0 27.0 11.0 17.0 15.0
#  13.0 12.0 16.0 10.0 31.0 18.0 nan 24.0 35.0 28.0 20.0 26.0 34.0 23.0 5.0
#  19.0 126.0 7.0 36.0 127.0]
#
# NumberOfPersonVisiting:[3 2 1 4 5]
#
# NumberOfFollowups:[3.0 4.0 2.0 5.0 nan 1.0 6.0]
#
# PreferredPropertyStar:[3.0 4.0 5.0 nan]
#
# NumberOfTrips:[1.0 2.0 7.0 5.0 6.0 3.0 4.0 19.0 21.0 8.0 nan 20.0 22.0]
#
# Passport:[1 0]
#
# PitchSatisfactionScore:[2 3 5 4 1]
#
# OwnCar:[1 0]
#
# NumberOfChildrenVisiting:[0.0 2.0 1.0 nan 3.0]
#
# MonthlyIncome:[20993.0 20130.0 17090.0 ... 22097.0 22995.0 21471.0]

# %%
for i in df[cols_cat].columns:
    x = df[i].unique()
    print(f"{i}:{x}")
    print()
# Out:
# TypeofContact:['Self Enquiry' 'Company Invited' nan]
#
# Occupation:['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
#
# Gender:['Female' 'Male']
#
# ProductPitched:['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
#
# MaritalStatus:['Single' 'Divorced' 'Married' 'Unmarried']
#
# Designation:['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
sns.scatterplot(x = 'Age', y = 'DurationOfPitch', data = df ,hue ='Gender' , palette = 'muted')
# Out:
# <Axes: xlabel='Age', ylabel='DurationOfPitch'>

# %%
cross_tab = pd.crosstab(df['MaritalStatus'] , df['ProdTaken'], normalize = 'index')

# %%
cross_tab
# Out:
# ProdTaken             0         1
# MaritalStatus
# Divorced       0.869474  0.130526
# Married        0.860684  0.139316
# Single         0.668122  0.331878
# Unmarried      0.756598  0.243402

# %%
cross_tab.plot(kind ='bar', stacked = 'True', color = ['skyblue', 'r'])
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(df['Age'], df['MonthlyIncome'], df['DurationOfPitch'], c=df['ProdTaken'], cmap = 'viridis')
ax.set_xlabel("Age")
ax.set_ylabel("Monthly Income")
ax.set_zlabel("Duration of Pitch")
ax.set_title('3d plot')
plt.show()

# %%
df
# Out:
#      CustomerID ProdTaken   Age    TypeofContact CityTier DurationOfPitch  \
# 0        200000         1  41.0     Self Enquiry        3             6.0
# 1        200001         0  49.0  Company Invited        1            14.0
# 2        200002         1  37.0     Self Enquiry        1             8.0
# 3        200003         0  33.0  Company Invited        1             9.0
# 4        200004         0   NaN     Self Enquiry        1             8.0
# ...         ...       ...   ...              ...      ...             ...
# 4883     204883         1  49.0     Self Enquiry        3             9.0
# 4884     204884         1  28.0  Company Invited        1            31.0
# 4885     204885         1  52.0     Self Enquiry        3            17.0
# 4886     204886         1  19.0     Self Enquiry        3            16.0
# 4887     204887         1  36.0     Self Enquiry        1            14.0
#
#           Occupation  Gender NumberOfPersonVisiting NumberOfFollowups  \
# ...

# %%
df['Total_visiting'] = df.NumberOfPersonVisiting + df.NumberOfChildrenVisiting

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...
